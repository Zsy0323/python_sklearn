# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from pandas import DataFrame,Series

# %% [markdown]
# ## PythonMan VS JavaMan

# %% [markdown]
# 这是PMan和JMan

# %%
PMan1 = plt.imread('PMan.png')
plt.imshow(PMan1)

# %%
JMan1 = plt.imread("JMan.png")
plt.imshow(JMan1)

# %% [markdown]
# PMan 和 JMa路上相遇,发生口角,继而大打出手

# %% [markdown]
# PMan一身现代武器,而JMan身怀绝技使用冷兵器

# %%
PMan = DataFrame({'弹药量':[150,60,30,10],'剩余量':[150,60,30,10]},index=['自动步枪','手枪','狙击枪','手榴弹'])
PMan
# Out:
#       弹药量  剩余量
# 自动步枪  150  150
# 手枪     60   60
# 狙击枪    30   30
# 手榴弹    10   10

# %%
JMan = DataFrame({'武器量':[1,1,2,10],'剩余量':[1,1,2,10]},index=['平底锅','镰刀','双刺','飞镖'])
JMan
# Out:
#      武器量  剩余量
# 平底锅    1    1
# 镰刀     1    1
# 双刺     2    2
# 飞镖    10   10

# %% [markdown]
# PMan拿着步枪就是对JMan一顿扫射,JMan用平底锅接招,一梭子子弹下来,JMan的平底锅烂了

# %%
PMan['剩余量']['自动步枪'] -= 60
PMan
# Out:
#       弹药量  剩余量
# 自动步枪  150   90
# 手枪     60   60
# 狙击枪    30   30
# 手榴弹    10   10

# %%
s = ['破烂的平底锅','镰刀','双刺','飞镖']
JMan = JMan.reindex(s)
JMan
# Out:
#          武器量   剩余量
# 破烂的平底锅   NaN   NaN
# 镰刀       1.0   1.0
# 双刺       2.0   2.0
# 飞镖      10.0  10.0

# %% [markdown]
# JMan很生气,把飞镖全部向他扔去

# %%
j = JMan.iloc[:3]
j
# Out:
#         武器量  剩余量
# 破烂的平底锅  NaN  NaN
# 镰刀      1.0  1.0
# 双刺      2.0  2.0

# %% [markdown]
# PMan用手枪把大部分飞镖击落,但还是有一个中了他的肩膀

# %%
PMan['剩余量']['手枪'] -= 45
PMan
# Out:
#       弹药量  剩余量
# 自动步枪  150   90
# 手枪     60   15
# 狙击枪    30   30
# 手榴弹    10   10

# %% [markdown]
# 受伤的PMan没拿住步枪和手枪,只好一直利用狙击枪射击JMan

# %%
p = PMan.iloc[2:4]
p
# Out:
#      弹药量  剩余量
# 狙击枪   30   30
# 手榴弹   10   10

# %%
p['剩余量']['狙击枪'] -= 30
p
# Out:
# d:\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
#      弹药量  剩余量
# 狙击枪   30    0
# 手榴弹   10   10

# %% [markdown]
# JMan慌乱之中,镰刀被打断,恼羞成怒的他手持双刺径直向PMan冲过来

# %%
j.iloc[2:3]
# Out:
#     武器量  剩余量
# 双刺  2.0  2.0

# %% [markdown]
# PMan看着手里的手榴弹,狙击枪一扔,也向JMan冲去

# %%
p.loc[['手榴弹']]
# Out:
#      弹药量  剩余量
# 手榴弹   10   10

# %% [markdown]
# 最后PMan引爆的手雷,Jman被炸翻在地,Pman自己也倒在地上

# %%
JMan2 = JMan1[::-1]
plt.imshow(JMan2)

# %%
finish = plt.imread('finish.png')
plt.imshow(finish)

# %% [markdown]
# 最后画面一变,    剧终

# %%
f2 = finish[::,::,::-1]
plt.imshow(f2)
